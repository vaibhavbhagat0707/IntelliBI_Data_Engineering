-- %%
SELECT * FROM vb_dev_cat.schema_dev_db.department;

INSERT INTO vb_dev_cat.schema_dev_db.department
VALUES
   (10, 'FINANCE', 'PUNE'),
   (10, 'FINANCE', 'MUMBAI'),
   (30, 'IT', 'HYD'),
   (40, 'ADMIN', 'HYD'),
   (50, 'HR', 'PUNE'),
   (60, 'SOFTWARE', 'MUMBAI'),
   (70, 'SOFTWARE', 'PUNE'),
   (80, 'SOFTWARE', 'MUMBAI'),
   (90, 'SOFTWARE', 'HYD')
;
-- Out:
-- Databricks visualization. Run in Databricks to view.
