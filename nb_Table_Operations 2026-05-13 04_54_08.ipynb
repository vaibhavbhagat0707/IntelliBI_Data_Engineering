# %%
# %sql
CREATE TABLE intelibi_data_engineering.intellibi_data.employee_managed (
    emp_id INT,
    emp_name STRING,
    salary DOUBLE
);

# %%
# %sql
INSERT INTO intelibi_data_engineering.intellibi_data.employee_managed
VALUES
(1, 'John', 50000),
(2, 'Sam', 60000);

# %%
# %sql
SELECT * FROM intelibi_data_engineering.intellibi_data.employee_managed;

# %%
# %sql
DESCRIBE EXTENDED intelibi_data_engineering.intellibi_data.employee_managed;
