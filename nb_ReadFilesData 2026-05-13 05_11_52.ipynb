# %%
# %sql
LIST "/Volumes/intelibi_data_engineering/intellibi_data/vol_intellibi_data/"

# %%
LIST "/Volumes/intelibi_data_engineering/intellibi_data/vol_intellibi_data/"

# %%
dfDepartment =  spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("/Volumes/intelibi_data_engineering/intellibi_data/vol_intellibi_data/departments.csv")
dfDepartment.printSchema()
dfDepartment.display()

# %%
dfDepartment.write.saveAsTable("intelibi_data_engineering.intellibi_data.departments")

# %%
# %sql 
SHOW TABLES IN Intelibi_data_engineering.intellibi_data;

# %%
# %sql
describe DETAIL Intelibi_data_engineering.Intellibi_data.departments;

# %%
# %sql
DESCRIBE EXTENDED intelibi_data_engineering.intellibi_data.departments;

# %%
# %sql SELECT * FROM  intelibi_data_engineering.intellibi_data.departments

# %%
dfdept = spark.table("intelibi_data_engineering.intellibi_data.departments")
dfdept.display()
