# %%
# %sql
CREATE CATALOG INTELIBI_DATA_ENGINEERING

# %%
# %sql
CREATE SCHEMA INTELIBI_DATA_ENGINEERING.INTELLIBI_DATA

# %%
# %sql
SHOW CATALOGS;
    
SHOW SCHEMAS IN INTELIBI_DATA_ENGINEERING;
    
SHOW TABLES IN INTELIBI_DATA_ENGINEERING.INTELLIBI_DATA;
    
-- DROP SCHEMA IF EXISTS INTELIBI_DATA_ENGINEERING.INTELLIBI_DATA CASCADE
    
-- DROP CATALOG IF

# %%
# %sql

SHOW SCHEMAS IN INTELIBI_DATA_ENGINEERING;

# %%
SHOW TABLES IN INTELIBI_DATA_ENGINEERING.INTELLIBI_DATA;
